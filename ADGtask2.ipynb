# %% [markdown]
# <a href="https://colab.research.google.com/github/NeelGhoshal/ADGtask/blob/main/ADGtask2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("kc_house_data.csv")
df
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
df=df.filter(['sqft_living','price'],axis=1)
df
# Out:
#        sqft_living     price
# 0             1180  221900.0
# 1             2570  538000.0
# 2              770  180000.0
# 3             1960  604000.0
# 4             1680  510000.0
# ...            ...       ...
# 21608         1530  360000.0
# 21609         2310  400000.0
# 21610         1020  402101.0
# 21611         1600  400000.0
# 21612         1020  325000.0
#
# [21613 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.scatter(df.sqft_living,df.price)
plt.show()

# %%
import numpy as np
def gradient_descent(x,y):
  m_curr=b_curr=0 
  iterations=100
  n=len(x)
  learning_rate=0.001 
  for i in range(iterations):
    y_predicted=m_curr*x+b_curr
    cost=(1/n)*sum([val**2 for val in (y-y_predicted) ]) 
    md=-(2/n)*sum(x*(y-y_predicted))  
    bd=-(2/n)*sum(y-y_predicted)
    m_curr=m_curr-learning_rate*md
    b_curr=b_curr-learning_rate*bd
 
  print(m_curr)
  print(b_curr)
x=(df.sqft_living)
y=(df.price) 

gradient_descent(x,y)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-12-cebfc0e68650> in <module>()
#      18 y=(df.price)
#      19
# ---> 20 gradient_descent(x,y)
#
# <ipython-input-12-cebfc0e68650> in gradient_descent(x, y)
#       7   for i in range(iterations):
#       8     y_predicted=m_curr*x+b_curr
# ----> 9     cost=(1/n)*sum([val**2 for val in (y-y_predicted) ])
#      10     md=-(2/n)*sum(x*(y-y_predicted))
#      11     bd=-(2/n)*sum(y-y_predicted)
#
# <ipython-input-12-cebfc0e68650> in <listcomp>(.0)
#       7   for i in range(iterations):
#       8     y_predicted=m_curr*x+b_curr
# ----> 9     cost=(1/n)*sum([val**2 for val in (y-y_predicted) ])
#      10     md=-(2/n)*sum(x*(y-y_predicted))
#      11     bd=-(2/n)*sum(y-y_predicted)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
from sklearn import linear_model
reg= linear_model.LinearRegression()
reg.fit([df.sqft_living],[df.price])
reg.predict(1500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbaf0cdfbdd2> in <module>()
#       1 from sklearn import linear_model
#       2 reg= linear_model.LinearRegression()
# ----> 3 reg.fit([df.sqft_living],[df.price])
#       4 reg.predict(1500)
#
# NameError: name 'df' is not defined
